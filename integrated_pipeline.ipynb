# %%
import cv2
import numpy as np
import tensorflow as tf
from ultralytics import YOLO
import nbimporter
from preprocess import preprocess_frame, detect_defects

# %%
# Load the CNN model from Phase 4
cnn_model = tf.keras.models.load_model(r"C:\Users\Sourav Kumar\OneDrive\Desktop\major project\best_fabric_defect_classifier.keras")

# Load the pre-trained YOLOv11 model with corrected path
yolo_model = YOLO(r"C:\Users\Sourav Kumar\OneDrive\Desktop\major project\FRONTEND\runs\detect\welding_defect2\weights\best.pt")

# Open webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break
    
    # Step 1: Use YOLOv11 to detect and localize defects in the entire frame
    results = yolo_model(frame)
    defect_detected = False
    defect_info = []

    # Process each detection
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])
            defect_name = yolo_model.names[cls]

            if conf > 0.5:  # Confidence threshold for YOLOv11 detection
                # Extract the detected region (automatic ROI)
                roi = frame[y1:y2, x1:x2]
                if roi.size == 0:
                    continue

                # Step 2: Preprocess ROI for CNN
                try:
                    cnn_input = cv2.resize(roi, (224, 224))
                    cnn_input = np.expand_dims(cnn_input / 255.0, axis=0)  # Normalize and add batch dimension

                    # Step 3: Use CNN to classify the detected region as Defect or No Defect
                    cnn_pred = cnn_model.predict(cnn_input, verbose=0)[0][0]
                    is_defective = cnn_pred > 0.5

                    if is_defective:
                        defect_detected = True
                        # Draw bounding box and label
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                        label = f"{defect_name} {conf:.2f} (CNN: Defect)"
                        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
                        defect_info.append(f"{defect_name} ({conf:.2f})")
                    else:
                        # If CNN says No Defect, still show YOLO detection but mark as non-defective
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        label = f"{defect_name} {conf:.2f} (CNN: No Defect)"
                        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                except Exception as e:
                    print(f"Error processing ROI: {e}")
                    continue

    # Step 4: Add overall frame label
    overall_label = "Defect Detected" if defect_detected else "No Defect"
    overall_color = (0, 0, 255) if defect_detected else (0, 255, 0)
    cv2.putText(frame, overall_label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, overall_color, 2)

    # Display defect types if any
    if defect_info:
        cv2.putText(frame, f"Defect Types: {', '.join(defect_info)}", (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('Weld Inspection', frame)
    
    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Clean up
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 colors, 1 thread, 97.6ms
# Speed: 3.5ms preprocess, 97.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 97.9ms
# Speed: 2.7ms preprocess, 97.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 116.0ms
# Speed: 2.7ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 101.5ms
# Speed: 2.7ms preprocess, 101.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 116.0ms
# Speed: 2.7ms preprocess, 116.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 102.4ms
# Speed: 2.4ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 98.4ms
# Speed: 2.2ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 95.4ms
# Speed: 1.5ms preprocess, 95.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 134.6ms
# Speed: 3.2ms preprocess, 134.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 78.4ms
# Speed: 2.0ms preprocess, 78.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 86.0ms
# Speed: 1.7ms preprocess, 86.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 colors, 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 colors, 80.5ms
# Speed: 2.1ms preprocess, 80.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 1 thread, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 2 threads, 83.2ms
# Speed: 1.5ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 1 thread, 79.4ms
# Speed: 1.9ms preprocess, 79.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 79.7ms
# Speed: 1.7ms preprocess, 79.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 83.0ms
# Speed: 1.7ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 1 thread, 74.9ms
# Speed: 1.7ms preprocess, 74.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 75.6ms
# Speed: 1.8ms preprocess, 75.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 1 thread, 74.4ms
# Speed: 1.8ms preprocess, 74.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 73.8ms
# Speed: 1.4ms preprocess, 73.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 75.0ms
# Speed: 1.4ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 70.7ms
# Speed: 1.7ms preprocess, 70.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 71.9ms
# Speed: 1.7ms preprocess, 71.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 72.1ms
# Speed: 1.8ms preprocess, 72.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 73.8ms
# Speed: 1.6ms preprocess, 73.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 76.1ms
# Speed: 2.6ms preprocess, 76.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 1 thread, 73.0ms
# Speed: 1.7ms preprocess, 73.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 71.6ms
# Speed: 1.6ms preprocess, 71.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 72.8ms
# Speed: 1.9ms preprocess, 72.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 colors, 75.1ms
# Speed: 1.8ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 72.6ms
# Speed: 1.6ms preprocess, 72.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 75.5ms
# Speed: 1.8ms preprocess, 75.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 75.3ms
# Speed: 1.7ms preprocess, 75.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 2 threads, 71.6ms
# Speed: 1.5ms preprocess, 71.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 75.2ms
# Speed: 1.5ms preprocess, 75.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 71.4ms
# Speed: 1.4ms preprocess, 71.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 72.8ms
# Speed: 1.6ms preprocess, 72.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 2 threads, 72.8ms
# Speed: 2.6ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 75.1ms
# Speed: 1.9ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 75.2ms
# Speed: 1.8ms preprocess, 75.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 79.0ms
# Speed: 1.4ms preprocess, 79.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 75.8ms
# Speed: 3.1ms preprocess, 75.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 79.2ms
# Speed: 1.5ms preprocess, 79.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 76.4ms
# Speed: 1.7ms preprocess, 76.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 97.6ms
# Speed: 1.7ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 90.1ms
# Speed: 2.3ms preprocess, 90.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 76.5ms
# Speed: 1.7ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 color, 1 thread, 73.5ms
# Speed: 1.6ms preprocess, 73.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 color, 1 thread, 73.3ms
# Speed: 2.4ms preprocess, 73.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 73.0ms
# Speed: 1.9ms preprocess, 73.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 colors, 1 thread, 72.9ms
# Speed: 1.5ms preprocess, 72.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
